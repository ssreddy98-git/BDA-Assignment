# %% [markdown]
# <a href="https://colab.research.google.com/github/ssreddy98-git/BDA-Assignment/blob/main/ICP6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Use the Sequential API to build a simple feedforward neural network.
# 2. Include 5 hidden layers with ReLU activation and an output layer with
# Softmax activation.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Create a Sequential model
model = Sequential()

# Flatten images to vectors of size 784
model.add(Flatten(input_shape=(28, 28)))

# Add 5 hidden layers with ReLU activation (you can change neurons here)
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output layer with 10 neurons (classes) and softmax activation
model.add(Dense(10, activation='softmax'))

# Compile with optimizer of your choice (try 'adam', 'sgd', 'rmsprop')
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train,
          epochs=10,          # More epochs to help reach higher accuracy
          batch_size=32,
          validation_split=0.2)

# Evaluate on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8378 - loss: 0.5187 - val_accuracy: 0.9562 - val_loss: 0.1471
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9665 - loss: 0.1145 - val_accuracy: 0.9635 - val_loss: 0.1221
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9745 - loss: 0.0807 - val_accuracy: 0.9657 - val_loss: 0.1249
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9823 - loss: 0.0567 - val_accuracy: 0.9672 - val_loss: 0.1127
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9854 - loss: 0.0460 - val_accuracy: 0.9710 - val_loss: 0.1014
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9893 - loss: 0.0343 - val_accuracy: 0.9761 - val_loss: 0.0932
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9900 - loss: 0.0317 - val_accuracy: 0.9737 - val_loss: 0.1097
# Epoch 8/10
# ...

# %% [markdown]
# 3. Try adding more layers or using a different number of neurons.
# 4. Experiment with different activation functions (e.g., tanh, sigmoid).
# 5. Compare results with different optimizers like sgd, rmsprop, etc.
#
# Note: Trying different activation functions in hidden layer and output layer and using rmsprop optimiser

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Create a Sequential model
model = Sequential()

# Flatten images to vectors of size 784
model.add(Flatten(input_shape=(28, 28)))

# Add 5 hidden layers with ReLU activation (you can change neurons here)
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='tanh'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='sigmoid'))

# Output layer with 10 neurons (classes) and sigmoid activation
model.add(Dense(10, activation='sigmoid'))

# Compile with optimizer of your choice (try 'adam', 'sgd', 'rmsprop')
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train,
          epochs=10,          # More epochs to help reach higher accuracy
          batch_size=32,
          validation_split=0.2)

# Evaluate on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.7765 - loss: 0.9248 - val_accuracy: 0.9413 - val_loss: 0.2207
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.9592 - loss: 0.1588 - val_accuracy: 0.9647 - val_loss: 0.1383
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9721 - loss: 0.1065 - val_accuracy: 0.9718 - val_loss: 0.1147
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9793 - loss: 0.0803 - val_accuracy: 0.9668 - val_loss: 0.1320
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9831 - loss: 0.0640 - val_accuracy: 0.9761 - val_loss: 0.0967
# Epoch 6/10
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Create a Sequential model
model = Sequential()

# Flatten images to vectors of size 784
model.add(Flatten(input_shape=(28, 28)))

# Add 5 hidden layers with ReLU activation (you can change neurons here)
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output layer with 10 neurons (classes) and sigmoid activation
model.add(Dense(10, activation='softmax'))

# Compile with optimizer of your choice (try 'adam', 'sgd', 'rmsprop')
model.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train,
          epochs=12,          # More epochs to help reach higher accuracy
          batch_size=32,
          validation_split=0.2)

# Evaluate on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4904 - loss: 1.5364 - val_accuracy: 0.9087 - val_loss: 0.3176
# Epoch 2/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9113 - loss: 0.3030 - val_accuracy: 0.9340 - val_loss: 0.2248
# Epoch 3/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9397 - loss: 0.2021 - val_accuracy: 0.9483 - val_loss: 0.1710
# Epoch 4/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9531 - loss: 0.1568 - val_accuracy: 0.9588 - val_loss: 0.1402
# Epoch 5/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9657 - loss: 0.1204 - val_accuracy: 0.9551 - val_loss: 0.1426
# Epoch 6/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9682 - loss: 0.1067 - val_accuracy: 0.9638 - val_loss: 0.1233
# Epoch 7/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9751 - loss: 0.0855 - val_accuracy: 0.9672 - val_loss: 0.1095
# Epoch 8/12
# ...

# %% [markdown]
# 6. Your model should achieve a test accuracy above 99%, given the
# simplicity of the dataset.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Create a Sequential model
model = Sequential()

# Flatten images to vectors of size 784
model.add(Flatten(input_shape=(28, 28)))

# Add 5 hidden layers with ReLU activation (you can change neurons here)
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output layer with 10 neurons (classes) and sigmoid activation
model.add(Dense(10, activation='softmax'))

# Compile with optimizer of your choice (try 'adam', 'sgd', 'rmsprop')
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train,
          epochs=20,          # More epochs to help reach higher accuracy
          batch_size=32,
          validation_split=0.2)

# Evaluate on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8385 - loss: 0.5277 - val_accuracy: 0.9639 - val_loss: 0.1250
# Epoch 2/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - accuracy: 0.9673 - loss: 0.1110 - val_accuracy: 0.9668 - val_loss: 0.1146
# Epoch 3/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9780 - loss: 0.0721 - val_accuracy: 0.9705 - val_loss: 0.1009
# Epoch 4/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9828 - loss: 0.0565 - val_accuracy: 0.9740 - val_loss: 0.0973
# Epoch 5/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9847 - loss: 0.0488 - val_accuracy: 0.9731 - val_loss: 0.0994
# Epoch 6/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9875 - loss: 0.0384 - val_accuracy: 0.9691 - val_loss: 0.1250
# Epoch 7/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9882 - loss: 0.0337 - val_accuracy: 0.9762 - val_loss: 0.0962
# Epoch 8/12
# ...

# %% [markdown]
# Video link: https://drive.google.com/file/d/1-7xIhPipXy6eX3yOfvO7GeMkPaksbjo_/view?usp=sharing
